# %%
import pandas as pd
import numpy as np

# %%
series = pd.Series(15)

# %%
print(series)
# Out:
# 0    15
# dtype: int64

# %%
series1 = pd.Series([10,9,7,8], index = ['color', 'size', 'size', 'wgt'])

# %%
series1
# Out:
# color    10
# size      9
# size      7
# wgt       8
# dtype: int64

# %%
series2 = pd.Series([10,10,10], index = ['size', 'price', 'wgt'])

# %%
series1+series2
# Out:
# color     NaN
# price     NaN
# size     19.0
# size     17.0
# wgt      18.0
# dtype: float64

# %%
x = pd.Series(np.arange(1,4))
x
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
ls
# Out:
# Lab1_tyler_iams.ipynb  Untitled.ipynb         titanic.csv

# %%
df = pd.read_csv('titanic.csv')

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %%
df.describe()
# Out:
#          Survived      Pclass         Age  Siblings/Spouses Aboard  \
# count  887.000000  887.000000  887.000000               887.000000
# mean     0.385569    2.305524   29.471443                 0.525366
# std      0.487004    0.836662   14.121908                 1.104669
# min      0.000000    1.000000    0.420000                 0.000000
# 25%      0.000000    2.000000   20.250000                 0.000000
# 50%      0.000000    3.000000   28.000000                 0.000000
# 75%      1.000000    3.000000   38.000000                 1.000000
# max      1.000000    3.000000   80.000000                 8.000000
#
#        Parents/Children Aboard       Fare
# count               887.000000  887.00000
# mean                  0.383315   32.30542
# std                   0.807466   49.78204
# min                   0.000000    0.00000
# 25%                   0.000000    7.92500
# 50%                   0.000000   14.45420
# 75%                   0.000000   31.13750
# ...

# %%
df.loc[:,['Survived', 'Fare']].head(9)
# Out:
#    Survived     Fare
# 0         0   7.2500
# 1         1  71.2833
# 2         1   7.9250
# 3         1  53.1000
# 4         0   8.0500
# 5         0   8.4583
# 6         0  51.8625
# 7         0  21.0750
# 8         1  11.1333

# %%
df.sort_values(by=['Fare'], ascending=False)
# Out:
#      Survived  Pclass                               Name     Sex   Age  \
# 676         1       1  Mr. Thomas Drake Martinez Cardeza    male  36.0
# 257         1       1                    Miss. Anna Ward  female  35.0
# 733         1       1              Mr. Gustave J Lesurer    male  35.0
# 87          1       1          Miss. Mabel Helen Fortune  female  23.0
# 435         0       1                   Mr. Mark Fortune    male  64.0
# ..        ...     ...                                ...     ...   ...
# 818         0       1     Jonkheer. John George Reuchlin    male  38.0
# 463         0       2               Mr. William Campbell    male  21.0
# 269         1       3        Mr. William Henry Tornquist    male  25.0
# 811         0       1                    Mr. Richard Fry    male  39.0
# 261         0       1               Mr. William Harrison    male  40.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard      Fare
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.countplot(x = df['Pclass'], data = df)

# %%
sns.scatterplot(x = df['Fare'], y = df['Survived'], data = df)

# %%
df2 = df[(df.Survived == 1) & (df.Pclass == 3)]

# %%
df2
# Out:
#      Survived  Pclass                                              Name  \
# 2           1       3                             Miss. Laina Heikkinen
# 8           1       3  Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 10          1       3                    Miss. Marguerite Rut Sandstrom
# 19          1       3                            Mrs. Fatima Masselmani
# 22          1       3                                Miss. Anna McGowan
# ..        ...     ...                                               ...
# 834         1       3                                    Mr. Chang Chip
# 851         1       3                         Mrs. Sam (Leah Rosen) Aks
# 854         1       3              Mrs. Solomon (Latifa Qurban) Baclini
# 865         1       3                    Master. Harold Theodor Johnson
# 871         1       3                          Miss. Adele Kiamie Najib
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %%
# Out:
#      Survived  Pclass                                              Name  \
# 2           1       3                             Miss. Laina Heikkinen
# 8           1       3  Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 10          1       3                    Miss. Marguerite Rut Sandstrom
# 19          1       3                            Mrs. Fatima Masselmani
# 22          1       3                                Miss. Anna McGowan
# ..        ...     ...                                               ...
# 834         1       3                                    Mr. Chang Chip
# 851         1       3                         Mrs. Sam (Leah Rosen) Aks
# 854         1       3              Mrs. Solomon (Latifa Qurban) Baclini
# 865         1       3                    Master. Harold Theodor Johnson
# 871         1       3                          Miss. Adele Kiamie Najib
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...
